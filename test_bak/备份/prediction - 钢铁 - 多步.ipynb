# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
from sklearn import preprocessing
from keras.layers.core import Dense, Activation, Dropout
from keras.layers.recurrent import LSTM
from keras.models import Sequential
from keras import metrics
# Out:
# Using TensorFlow backend.
# e:\envs\python36env\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# e:\envs\python36env\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# e:\envs\python36env\lib\site-packages\tensorflow\python\framework\dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# e:\envs\python36env\lib\site-packages\tensorflow\python\framework\dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# e:\envs\python36env\lib\site-packages\tensorflow\python\framework\dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# e:\envs\python36env\lib\site-packages\tensorflow\python\framework\dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
data_xls = pd.read_excel('辽宁钢铁行业月用电量.xls')

# %%
data_xls
# Out:
#           月份  辽宁钢铁行业月用电量（亿千万时）    钢铁产量   汽车产量      水泥产量  金属切削机床   大中型拖拉机  \
# 0    2007M01         13.856687  354.62  78.72   8370.22    4.12  14440.0
# 1    2007M02         11.941298  318.87  59.65   6500.82    3.35  13941.0
# 2    2007M03         14.555307  368.91  88.96   9308.57    4.78  26231.0
# 3    2007M04         13.656541  366.22  83.98  11643.56    5.41  22263.0
# 4    2007M05         13.143799  374.81  74.35  12869.06    5.34  14824.0
# ..       ...               ...     ...    ...       ...     ...      ...
# 153  2019M10         19.591677  609.31    NaN       NaN     NaN      NaN
# 154  2019M11         21.042283  630.76    NaN       NaN     NaN      NaN
# 155  2019M12         21.137609  648.00    NaN       NaN     NaN      NaN
# 156  2020M01         22.502425  621.00    NaN       NaN     NaN      NaN
# 157  2020M02         19.675281  525.78    NaN       NaN     NaN      NaN
#
#       鞍钢股价   本钢股价   凌钢股价
# 0    12.95   6.50   6.10
# 1    12.87   8.09   7.58
# 2    14.57   8.55   8.28
# 3    17.64  13.35  11.03
# 4    18.34  13.89  10.44
# ..     ...    ...    ...
# 153    NaN    NaN    NaN
# 154    NaN    NaN    NaN
# 155    NaN    NaN    NaN
# 156    NaN    NaN    NaN
# 157    NaN    NaN    NaN
#
# [158 rows x 10 columns]

# %%
# data_xls.drop(['月份'], axis=1, inplace=True)
# data_xls

# %%
data_origin = np.array(data_xls)[:,1]

# %%
data_origin
# Out:
# array([13.85668698, 11.94129775, 14.5553069, 13.65654085, 13.14379943,
#        13.89728023, 13.82012254, 13.79591637, 13.98148773, 13.27588781,
#        13.96807882, 14.28233571, 14.25003836, 12.63311045, 13.46243023,
#        12.66591199, 15.74872233, 13.96355619, 14.0412472, 14.73483898,
#        14.43095576, 13.07001702, 11.2565999, 12.75663418, 15.18040114,
#        13.37540347, 14.73297642, 15.78046701, 17.72041254, 17.83488148,
#        18.58404608, 20.17703177, 18.09534907, 18.75590088, 18.23257587,
#        19.43319581, 21.23330098, 16.1386489, 19.02165091, 19.05428623,
#        19.68678322, 19.79838388, 19.47129446, 21.33109174, 21.66244321,
#        21.55903074, 21.76134192, 21.32224764, 23.88102624, 20.37005115,
#        22.57014853, 22.31149827, 23.46213236, 23.0468898, 23.68748431,
#        23.21969118, 22.34132092, 22.57994124, 20.77764555, 21.62859336,
#        20.60581298, 19.12035023, 21.83852119, 22.03478112, 22.96754631,
#        21.99876057, 24.83276378, 21.62148723, 20.27768634, 22.63204252,
#        23.17493494, 23.35720146, 23.4494409, 20.05551726, 22.89831935,
#        23.94298725, 24.63203561, 23.35155973, 25.31567391, 26.24082889,
#        25.83558837, 24.00818065, 22.82075883, 23.84022494, 23.13291284,
#        19.77291608, 22.45914102, 24.02220376, 26.20990809, 24.59617107,
#        25.46253341, 25.24421981, 23.15790464, 21.54331805, 21.69186812,
#        21.25446054, 20.83566767, 17.95659335, 19.55274425, 20.89823355,
#        20.79405025, 20.84028229, 20.82683596, 20.78248827, 19.96580573,
#        20.25657528, 19.06249871, 19.74895734, 19.38375032, 17.4848425,
#        18.59874137, 20.10044633, 22.06121774, 19.92066993, 21.12960442,
#        21.07426005, 20.89839063, 20.15933505, 21.14000262, 22.6499205,
#        21.42764687, 17.89738074, 19.18840066, 17.67422009, 17.4675257,
#        18.42638918, 19.08247928, 19.73316095, 18.68432664, 20.36121768,
#        21.55439184, 25.15657524, 24.1482845, 20.06436585, 20.64947237,
#        18.09508135, 19.74620851, 20.58406331, 21.34571071, 21.82762467,
#        20.58568844, 21.29129811, 22.18582289, 24.19712964, 24.61261013,
#        21.01600025, 22.15678527, 20.91162269, 20.28238152, 19.91447554,
#        21.4835149, 21.12505014, 20.37748005, 19.59167681, 21.04228263,
#        21.13760913, 22.50242549, 19.67528052], dtype=object)

# %%
# #Max-Min标准化
# #建立MinMaxScaler对象
scaler = preprocessing.MinMaxScaler()

# # 标准化处理
# scaler = preprocessing.StandardScaler()

data = scaler.fit_transform(np.array(data_xls)[:,1].reshape(-1, 1))

data
# Out:
# array([[0.17352158],
#        [0.04569457],
#        [0.22014526],
#        [0.16016446],
#        [0.12594572],
#        [0.17623064],
#        [0.17108138],
#        [0.16946594],
#        [0.18185039],
#        [0.13476088],
#        [0.18095552],
#        [0.20192803],
#        [0.19977261],
#        [0.09186396],
#        [0.14721013],
#        [0.09405303],
#        [0.29979003],
#        [0.18065369],
#        [0.18583854],
#        [0.23212666],
#        [0.21184646],
#        [0.12102172],
#        [0.        ],
#        [0.10010754],
#        [0.26186207],
#        [0.14140224],
#        [0.23200236],
#        [0.30190857],
#        [0.43137439],
#        [0.43901368],
#        [0.48901056],
#        [0.59532138],
#        [0.45639647],
#        [0.5004796 ],
#        [0.46555455],
#        [0.54568012],
#        [0.66581344],
#        [0.32581249],
#        [0.51821492],
#        [0.5203929 ],
#        [0.56260374],
#        [0.57005162],
#        [0.54822271],
#        [0.67233969],
#        [0.69445304],
#        [0.68755161],
#        [0.70105322],
#        [0.67174946],
#        [0.84251424],
#        [0.60820288],
#        [0.75503041],
#        [0.73776892],
#        [0.81455859],
#        [0.78684662],
#        [0.82959787],
#        [0.79837883],
#        [0.73975918],
#        [0.75568395],
#        [0.63540444],
#        [0.692194  ],
#        [0.62393688],
#        [0.5248018 ],
#        [0.70620392],
#        [0.71930169],
#        [0.78155148],
#        [0.71689779],
#        [0.90603019],
#        [0.69171976],
#        [0.60203875],
#        [0.75916102],
#        [0.79539194],
#        [0.80755584],
#        [0.8137116 ],
#        [0.58721189],
#        [0.7769315 ],
#        [0.84664932],
#        [0.89263423],
#        [0.80717932],
#        [0.93825809],
#        [1.        ],
#        [0.97295553],
#        [0.85100013],
#        [0.77175535],
#        [0.83979129],
#        [0.79258752],
#        [0.56835198],
#        [0.74762213],
#        [0.85193598],
#        [0.99793644],
#        [0.89024074],
#        [0.94805902],
#        [0.93348947],
#        [0.7942554 ],
#        [0.686503  ],
#        [0.69641676],
#        [0.66722556],
#        [0.63927665],
#        [0.44713635],
#        [0.55365841],
#        [0.6434521 ],
#        [0.63649924],
#        [0.63958462],
#        [0.63868725],
#        [0.63572763],
#        [0.58122482],
#        [0.60062986],
#        [0.52094097],
#        [0.56675305],
#        [0.54238029],
#        [0.41565319],
#        [0.48999128],
#        [0.59021031],
#        [0.72106599],
#        [0.5782126 ],
#        [0.65889306],
#        [0.65519955],
#        [0.64346259],
#        [0.59414036],
#        [0.659587  ],
#        [0.76035414],
#        [0.67878347],
#        [0.44318469],
#        [0.52934327],
#        [0.42829165],
#        [0.41449752],
#        [0.47848904],
#        [0.52227441],
#        [0.56569885],
#        [0.49570297],
#        [0.60761336],
#        [0.68724203],
#        [0.92764034],
#        [0.86035021],
#        [0.58780241],
#        [0.62685057],
#        [0.4563786 ],
#        [0.5665696 ],
#        [0.62248538],
#        [0.67331531],
#        [0.70547672],
#        [0.62259383],
#        [0.66968399],
#        [0.72938174],
#        [0.86360998],
#        [0.89133784],
#        [0.65131148],
#        [0.72744386],
#        [0.64434565],
#        [0.60235209],
#        [0.57779921],
#        [0.68251193],
#        [0.65858912],
#        [0.60869866],
#        [0.55625664],
#        [0.65306548],
#        [0.65942727],
#        [0.75051079],
#        [0.56183609]])

# %%
data.shape
# Out:
# (158, 1)

# %%
data = data[:156,:]

# %%
data.shape
# Out:
# (156, 1)

# %%
# n = 0
# for i in range(data.shape[0]):
#     if data[i,0]<0:
#         n=n+1
# print(n)

# %%
# data_y = data[-146:-2,:]
# print(data_y.shape)

# %%
data_x = []
for r in range(133):
    for c in range(12):
        item = []
        item.append(data[r+c, 0])
        data_x.append(item)
data_x = np.array(data_x)
print(data_x)
print(data_x.shape)
# Out:
# [[0.17352158]
#  [0.04569457]
#  [0.22014526]
#  ...
#  [0.66968399]
#  [0.72938174]
#  [0.86360998]]
# (1596, 1)

# %%
data_x=data_x.reshape(133,12,1)

# %%
data_x.shape
# Out:
# (133, 12, 1)

# %%
data_x
# Out:
# array([[[0.17352158],
#         [0.04569457],
#         [0.22014526],
#         ...,
#         [0.13476088],
#         [0.18095552],
#         [0.20192803]],
#
#        [[0.04569457],
#         [0.22014526],
#         [0.16016446],
#         ...,
#         [0.18095552],
#         [0.20192803],
#         [0.19977261]],
#
#        [[0.22014526],
#         [0.16016446],
#         [0.12594572],
#         ...,
#         [0.20192803],
#         [0.19977261],
#         [0.09186396]],
#
#        ...,
#
#        [[0.68724203],
#         [0.92764034],
#         [0.86035021],
#         ...,
#         [0.70547672],
#         [0.62259383],
#         [0.66968399]],
#
#        [[0.92764034],
#         [0.86035021],
#         [0.58780241],
#         ...,
#         [0.62259383],
#         [0.66968399],
#         [0.72938174]],
#
#        [[0.86035021],
#         [0.58780241],
#         [0.62685057],
#         ...,
#         [0.66968399],
#         [0.72938174],
#         [0.86360998]]])

# %%
data_y = []
for r in range(12,145):
    for c in range(12):
        item = []
        item.append(data[r+c, 0])
        data_y.append(item)
data_y = np.array(data_y)
print(data_y)
print(data_y.shape)
# Out:
# [[0.19977261]
#  [0.09186396]
#  [0.14721013]
#  ...
#  [0.55625664]
#  [0.65306548]
#  [0.65942727]]
# (1596, 1)

# %%
data_y = data_y.reshape(133,12,1)

# %%
data_y
# Out:
# array([[[0.19977261],
#         [0.09186396],
#         [0.14721013],
#         ...,
#         [0.12102172],
#         [0.        ],
#         [0.10010754]],
#
#        [[0.09186396],
#         [0.14721013],
#         [0.09405303],
#         ...,
#         [0.        ],
#         [0.10010754],
#         [0.26186207]],
#
#        [[0.14721013],
#         [0.09405303],
#         [0.29979003],
#         ...,
#         [0.10010754],
#         [0.26186207],
#         [0.14140224]],
#
#        ...,
#
#        [[0.72938174],
#         [0.86360998],
#         [0.89133784],
#         ...,
#         [0.65858912],
#         [0.60869866],
#         [0.55625664]],
#
#        [[0.86360998],
#         [0.89133784],
#         [0.65131148],
#         ...,
#         [0.60869866],
#         [0.55625664],
#         [0.65306548]],
#
#        [[0.89133784],
#         [0.65131148],
#         [0.72744386],
#         ...,
#         [0.55625664],
#         [0.65306548],
#         [0.65942727]]])

# %%
data_x_train = data_x[:100,:, :]
data_y_train = data_y[:100,:,:]

data_x_test = data_x[-33:,:, :]
data_y_test = data_y[-33:,:,:]

# %%
# print(data_x_train.shape)
# print(data_y_test.shape)
# print(data_x_train.shape)
# print(data_y_test.shape)

# %%
#     model = Sequential()
 
#     model.add(LSTM(input_dim=10,output_dim=128,return_sequences=True))
#     model.add(Dropout(0.1))
 
#     model.add(LSTM(128,return_sequences=False))
#     model.add(Dropout(0.1))
 
#     model.add(Dense(output_dim=1))
#     model.add(Activation("linear"))
 
#     model.compile(loss="mse", optimizer="rmsprop")

# %%
# model = Sequential()

# model.add(LSTM(output_dim=128, 
#                 input_shape=(10, 1),
#                 activation='relu',
#                 return_sequences=True))
# for i in range(6):
#     model.add(LSTM(output_dim=128,
#                     activation='tanh',
#                     return_sequences=True))
# #     model.add(Dropout(0.1))

# model.add(LSTM(output_dim=1,
#                activation='linear',
#                return_sequences=False))

# model.compile(loss='mse', optimizer='adam', metrics=[metrics.mse])
# model.summary()

# %%
def create_model(output_dim1, num_layer, output_dim2):
    model = Sequential()

    model.add(LSTM(output_dim=output_dim1, 
                input_shape=(12, 1),
                activation='relu',
                return_sequences=True))
    for i in range(num_layer):
        model.add(LSTM(output_dim=output_dim2,
                        activation='tanh',
                        return_sequences=True))
#     model.add(Dropout(0.1))

    model.add(Dense(output_dim=1,
               activation='linear'))

    model.compile(loss='mse', optimizer='adam', metrics=[metrics.mse])
#     model.summary()
    return model

# %%
# from sklearn.model_selection import RandomizedSearchCV
# from skopt.space import Real, Categorical, Integer
# from keras.wrappers.scikit_learn import KerasRegressor
# from sklearn.model_selection import train_test_split

# %%
# #采用暴力搜索，所有参数进行组合，然后选择最好的参数
# tuned_parameters=[{'output_dim1':Integer(28, 128),
#                    'num_layer':Integer(3,12),
#                    'output_dim2':Integer(28, 128)}]
# # 'output_dim1':Integer(28, 128),
# #             'num_layer':Integer(3,12),
# #             'output_dim2':Integer(28, 128)

# %%
# train_x, test_x, train_y, test_y = train_test_split(data_x, data_y, train_size=0.80, random_state=0)

# %%
# model=KerasRegressor(build_fn=create_model)

# %%
# #采用随机搜索，给参数一个范围，然后系统随机选择参数，进行检验，然后选择最好的
# tuned_parameters={'output_dim1':[28, 64, 96,128],
#                    'num_layer':[4,5,6,7,8],
#                    'output_dim2':[28,64, 96,128]}

# lstm=RandomizedSearchCV(model,tuned_parameters,scoring='neg_mean_squared_error',n_iter=10)
 
# lstm.fit(data_x_train,data_y_train)

# %%
# print('最优训练器:',lstm.best_estimator_)
# print('最优训练器的精度:',lstm.best_score_)

# %%
# best_estimator_ = lstm.best_estimator_

# %%
# best_estimator_.predict(data_x_test,batch_size = 1)

# %%
# import sklearn
# sorted(sklearn.metrics.SCORERS.keys())

# %%
# from sklearn.model_selection import train_test_split
# from skopt import BayesSearchCV
# from skopt.space import Real, Categorical, Integer

# %%
# class FixedBayesSearchCV(BayesSearchCV):
#     """
#     Dirty hack to avoid compatibility issues with sklearn 0.2 and skopt.
#     Credit: https://www.kaggle.com/c/home-credit-default-risk/discussion/64004
#     For context, on why the workaround see:
#         - https://github.com/scikit-optimize/scikit-optimize/issues/718
#         - https://github.com/scikit-optimize/scikit-optimize/issues/762
#     """
#     def __init__(self, estimator, search_spaces, optimizer_kwargs=None,
#                 n_iter=50, scoring=None, fit_params=None, n_jobs=1,
#                 n_points=1, iid=True, refit=True, cv=None, verbose=0,
#                 pre_dispatch='2*n_jobs', random_state=None,
#                 error_score='raise', return_train_score=False):
#         """
#         See: https://github.com/scikit-optimize/scikit-optimize/issues/762#issuecomment-493689266
#         """
 
#         # Bug fix: Added this line
#         self.fit_params = fit_params
 
#         self.search_spaces = search_spaces
#         self.n_iter = n_iter
#         self.n_points = n_points
#         self.random_state = random_state
#         self.optimizer_kwargs = optimizer_kwargs
#         self._check_search_space(self.search_spaces)
 
#         # Removed the passing of fit_params to the parent class.
#         super(BayesSearchCV, self).__init__(
#                 estimator=estimator, scoring=scoring, n_jobs=n_jobs, iid=iid,
#                 refit=refit, cv=cv, verbose=verbose, pre_dispatch=pre_dispatch,
#                 error_score=error_score, return_train_score=return_train_score)
 
#     def _run_search(self, x):
#         raise BaseException('Use newer skopt')

# %%
# def lstm_auto_para_tuning_bayesian(model,data_x,data_y):
#     train_x, test_x, train_y, test_y = train_test_split(data_x, data_y, train_size=0.80, random_state=0)
#     # cv：交叉验证 n_points：并行采样的超参组数
#     opt = FixedBayesSearchCV(model,cv=5,n_points=2,n_jobs=4,verbose=1,
#         search_spaces={
#             'output_dim1':Integer(28, 128),
#             'num_layer':Integer(3,12),
#             'output_dim2':Integer(28, 128)
#         },
#          fit_params={
#                  'eval_set':[(test_x, test_y)],
#                  'eval_metric': 'mse',
#                  'early_stopping_rounds': 50
#                  })
#     opt.fit(train_x,train_y)
#     print("val. score: %s" % opt.best_score_)
#     print("test score: %s" % opt.score(test_x, test_y))
#     print("Best parameters: ", opt.best_params_)
#     print("Best estimator:", opt.best_estimator_)

# %%
model = create_model(32, 4, 32)
# Out:
# WARNING:tensorflow:From e:\envs\python36env\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# e:\envs\python36env\lib\site-packages\ipykernel_launcher.py:7: UserWarning: Update your `LSTM` call to the Keras 2 API: `LSTM(input_shape=(12, 1), activation="relu", return_sequences=True, units=32)`
#   import sys
# e:\envs\python36env\lib\site-packages\ipykernel_launcher.py:11: UserWarning: Update your `LSTM` call to the Keras 2 API: `LSTM(activation="tanh", return_sequences=True, units=32)`
#   # This is added back by InteractiveShellApp.init_path()
# e:\envs\python36env\lib\site-packages\ipykernel_launcher.py:15: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="linear", units=1)`
#   from ipykernel import kernelapp as app

# %%
# lstm_auto_para_tuning_bayesian(model,data_x,data_y)

# %%
model.fit(data_x_train, data_y_train, epochs=20, batch_size=100, verbose=1)
# Out:
# WARNING:tensorflow:From e:\envs\python36env\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/20
# 100/100 [==============================] - 10s 99ms/step - loss: 0.4384 - mean_squared_error: 0.4384
# Epoch 2/20
# 100/100 [==============================] - 0s 1ms/step - loss: 0.4286 - mean_squared_error: 0.4286
# Epoch 3/20
# 100/100 [==============================] - 0s 1ms/step - loss: 0.4171 - mean_squared_error: 0.4171
# Epoch 4/20
# 100/100 [==============================] - 0s 1ms/step - loss: 0.4043 - mean_squared_error: 0.4043
# Epoch 5/20
# 100/100 [==============================] - 0s 1ms/step - loss: 0.3903 - mean_squared_error: 0.3903
# Epoch 6/20
# 100/100 [==============================] - 0s 1ms/step - loss: 0.3750 - mean_squared_error: 0.3750
# Epoch 7/20
# 100/100 [==============================] - 0s 1ms/step - loss: 0.3582 - mean_squared_error: 0.3582
# Epoch 8/20
# 100/100 [==============================] - 0s 1ms/step - loss: 0.3400 - mean_squared_error: 0.3400
# Epoch 9/20
# 100/100 [==============================] - 0s 1ms/step - loss: 0.3201 - mean_squared_error: 0.3201
# Epoch 10/20
# 100/100 [==============================] - 0s 1ms/step - loss: 0.2985 - mean_squared_error: 0.2985
# Epoch 11/20
# 100/100 [==============================] - 0s 1ms/step - loss: 0.2754 - mean_squared_error: 0.2754
# Epoch 12/20
# 100/100 [==============================] - 0s 1ms/step - loss: 0.2510 - mean_squared_error: 0.2510
# Epoch 13/20
# 100/100 [==============================] - 0s 1ms/step - loss: 0.2258 - mean_squared_error: 0.2258
# Epoch 14/20
# 100/100 [==============================] - 0s 1ms/step - loss: 0.2011 - mean_squared_error: 0.2011
# Epoch 15/20
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1788 - mean_squared_error: 0.1788
# Epoch 16/20
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1621 - mean_squared_error: 0.1621
# Epoch 17/20
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1553 - mean_squared_error: 0.1553
# Epoch 18/20
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1604 - mean_squared_error: 0.1604
# Epoch 19/20
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1698 - mean_squared_error: 0.1698
# Epoch 20/20
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1738 - mean_squared_error: 0.1738

# %%
# 评估模型,不输出预测结果
loss,accuracy = model.evaluate(data_x_test,data_y_test)
print('\ntest loss','{:.5f}'.format(loss))
print('accuracy','{:.5f}'.format(accuracy))
# Out:
# 33/33 [==============================] - 1s 44ms/step
#
# test loss 0.16550
# accuracy 0.16550

# %%
y_pred = model.predict(data_x_test,batch_size = 1)

# %%
y_pred
# Out:
# array([[[0.06110515],
#         [0.11219218],
#         [0.1729945 ],
#         [0.24525452],
#         [0.33046326],
#         [0.42956242],
#         [0.5425567 ],
#         [0.66828614],
#         [0.80429786],
#         [0.9468593 ],
#         [1.0914419 ],
#         [1.2334404 ]],
#
#        [[0.06110751],
#         [0.11220141],
#         [0.17301409],
#         [0.24523726],
#         [0.33032152],
#         [0.429112  ],
#         [0.5415786 ],
#         [0.66655874],
#         [0.8015359 ],
#         [0.94284016],
#         [1.0861549 ],
#         [1.2271826 ]],
#
#        [[0.06110682],
#         [0.11219613],
#         [0.17295071],
#         [0.24502267],
#         [0.32976696],
#         [0.42798832],
#         [0.53964454],
#         [0.6634931 ],
#         [0.7970632 ],
#         [0.93689936],
#         [1.0790272 ],
#         [1.2192943 ]],
#
#        [[0.06110456],
#         [0.11214265],
#         [0.17275846],
#         [0.24450904],
#         [0.32870284],
#         [0.4261204 ],
#         [0.5366206 ],
#         [0.65898067],
#         [0.7909302 ],
#         [0.92937434],
#         [1.0705235 ],
#         [1.2103616 ]],
#
#        [[0.06106287],
#         [0.11198281],
#         [0.17231438],
#         [0.24356768],
#         [0.32702056],
#         [0.4233404 ],
#         [0.53237754],
#         [0.65308106],
#         [0.78353447],
#         [0.9208464 ],
#         [1.0614004 ],
#         [1.2012384 ]],
#
#        [[0.0610777 ],
#         [0.11198125],
#         [0.17224158],
#         [0.24333914],
#         [0.32641593],
#         [0.42207557],
#         [0.53026134],
#         [0.6501948 ],
#         [0.7800961 ],
#         [0.9172038 ],
#         [1.0579493 ],
#         [1.1983292 ]],
#
#        [[0.06101691],
#         [0.11176225],
#         [0.17173016],
#         [0.24226658],
#         [0.32444957],
#         [0.4189754 ],
#         [0.5260679 ],
#         [0.6451108 ],
#         [0.77449125],
#         [0.91154194],
#         [1.0526881 ],
#         [1.1938025 ]],
#
#        [[0.06105182],
#         [0.11188959],
#         [0.17191254],
#         [0.242408  ],
#         [0.3245149 ],
#         [0.41914633],
#         [0.5266059 ],
#         [0.6463451 ],
#         [0.7767457 ],
#         [0.9150459 ],
#         [1.0574806 ],
#         [1.1997797 ]],
#
#        [[0.06103324],
#         [0.11171038],
#         [0.17135388],
#         [0.24130416],
#         [0.32292238],
#         [0.41723302],
#         [0.5246604 ],
#         [0.64472544],
#         [0.7757993 ],
#         [0.91499853],
#         [1.0584533 ],
#         [1.2018583 ]],
#
#        [[0.06093702],
#         [0.11136515],
#         [0.17066604],
#         [0.24039395],
#         [0.32201222],
#         [0.41665092],
#         [0.52478886],
#         [0.64592123],
#         [0.7782767 ],
#         [0.9188411 ],
#         [1.0636861 ],
#         [1.2083695 ]],
#
#        [[0.06099337],
#         [0.11168203],
#         [0.1717094 ],
#         [0.24274525],
#         [0.32632932],
#         [0.42357793],
#         [0.534836  ],
#         [0.65930843],
#         [0.7949155 ],
#         [0.93840796],
#         [1.085573  ],
#         [1.2315818 ]],
#
#        [[0.06106973],
#         [0.11210887],
#         [0.17284341],
#         [0.24501908],
#         [0.33020258],
#         [0.42945993],
#         [0.5429636 ],
#         [0.6697417 ],
#         [0.807601  ],
#         [0.95308495],
#         [1.1015894 ],
#         [1.24809   ]],
#
#        [[0.06117009],
#         [0.11241607],
#         [0.17349386],
#         [0.24617308],
#         [0.33201563],
#         [0.43201038],
#         [0.54628825],
#         [0.6739276 ],
#         [0.81268996],
#         [0.9588321 ],
#         [1.107578  ],
#         [1.2537792 ]],
#
#        [[0.06106057],
#         [0.11202004],
#         [0.17259985],
#         [0.24455474],
#         [0.32941315],
#         [0.4282178 ],
#         [0.54129905],
#         [0.6678849 ],
#         [0.80564576],
#         [0.9508195 ],
#         [1.0985861 ],
#         [1.2438034 ]],
#
#        [[0.06112231],
#         [0.11227708],
#         [0.17323413],
#         [0.24572587],
#         [0.3312836 ],
#         [0.43103805],
#         [0.5453084 ],
#         [0.673023  ],
#         [0.8116026 ],
#         [0.9570392 ],
#         [1.1043973 ],
#         [1.2486265 ]],
#
#        [[0.06111948],
#         [0.11225567],
#         [0.17312242],
#         [0.24544999],
#         [0.33088562],
#         [0.43061897],
#         [0.5447711 ],
#         [0.67213017],
#         [0.8099703 ],
#         [0.95423657],
#         [1.1001229 ],
#         [1.2428142 ]],
#
#        [[0.06111048],
#         [0.11217799],
#         [0.17291492],
#         [0.2451618 ],
#         [0.3306223 ],
#         [0.43028632],
#         [0.54412025],
#         [0.6707395 ],
#         [0.8073374 ],
#         [0.9499682 ],
#         [1.0940723 ],
#         [1.2351284 ]],
#
#        [[0.06107273],
#         [0.11207183],
#         [0.17282087],
#         [0.24521902],
#         [0.3307746 ],
#         [0.43031093],
#         [0.5435942 ],
#         [0.66911256],
#         [0.80412024],
#         [0.94489294],
#         [1.0871788 ],
#         [1.2266712 ]],
#
#        [[0.06112285],
#         [0.11236461],
#         [0.17362829],
#         [0.24663022],
#         [0.33269843],
#         [0.43241635],
#         [0.5453498 ],
#         [0.669952  ],
#         [0.80360717],
#         [0.9428399 ],
#         [1.0835998 ],
#         [1.2218274 ]],
#
#        [[0.06120037],
#         [0.11262505],
#         [0.17397486],
#         [0.24678808],
#         [0.33217904],
#         [0.43057036],
#         [0.5415407 ],
#         [0.663733  ],
#         [0.79485565],
#         [0.9317182 ],
#         [1.0705991 ],
#         [1.2077215 ]],
#
#        [[0.06113759],
#         [0.11217081],
#         [0.17258403],
#         [0.24369532],
#         [0.32647514],
#         [0.4213943 ],
#         [0.52828   ],
#         [0.64619166],
#         [0.77324915],
#         [0.9067455 ],
#         [1.0434057 ],
#         [1.1798812 ]],
#
#        [[0.06095786],
#         [0.11148406],
#         [0.17088354],
#         [0.2403278 ],
#         [0.32077911],
#         [0.4128506 ],
#         [0.5166454 ],
#         [0.63148826],
#         [0.7558645 ],
#         [0.88746434],
#         [1.0234839 ],
#         [1.160743  ]],
#
#        [[0.06102331],
#         [0.1116787 ],
#         [0.17122807],
#         [0.24084508],
#         [0.3215482 ],
#         [0.41404924],
#         [0.5184634 ],
#         [0.6341754 ],
#         [0.7597598 ],
#         [0.89312595],
#         [1.0314773 ],
#         [1.1712327 ]],
#
#        [[0.06094658],
#         [0.11134549],
#         [0.17042351],
#         [0.23940101],
#         [0.31941727],
#         [0.41125423],
#         [0.5151769 ],
#         [0.6307807 ],
#         [0.75700897],
#         [0.89193183],
#         [1.0324458 ],
#         [1.1745617 ]],
#
#        [[0.06093615],
#         [0.11135234],
#         [0.17056194],
#         [0.23990825],
#         [0.32056883],
#         [0.41340777],
#         [0.51880795],
#         [0.6366309 ],
#         [0.7658837 ],
#         [0.90422297],
#         [1.0480232 ],
#         [1.1926914 ]],
#
#        [[0.06098464],
#         [0.111591  ],
#         [0.17125818],
#         [0.24137235],
#         [0.32319596],
#         [0.4177175 ],
#         [0.52560145],
#         [0.6468045 ],
#         [0.77993757],
#         [0.922109  ],
#         [1.0690119 ],
#         [1.2156461 ]],
#
#        [[0.06101792],
#         [0.11176568],
#         [0.17169857],
#         [0.24228452],
#         [0.3249373 ],
#         [0.42098927],
#         [0.53131175],
#         [0.65560293],
#         [0.7920435 ],
#         [0.9371158 ],
#         [1.0860847 ],
#         [1.2337809 ]],
#
#        [[0.06105102],
#         [0.11184887],
#         [0.1719081 ],
#         [0.24284132],
#         [0.32642022],
#         [0.42424092],
#         [0.5370106 ],
#         [0.66409785],
#         [0.8031295 ],
#         [0.95017946],
#         [1.1003151 ],
#         [1.2483786 ]],
#
#        [[0.06099772],
#         [0.11171424],
#         [0.17178556],
#         [0.24317247],
#         [0.32793579],
#         [0.42757303],
#         [0.54254633],
#         [0.67175186],
#         [0.81245935],
#         [0.9605596 ],
#         [1.1111144 ],
#         [1.2590803 ]],
#
#        [[0.06108303],
#         [0.11213755],
#         [0.1731677 ],
#         [0.24643216],
#         [0.33389816],
#         [0.43680167],
#         [0.5550837 ],
#         [0.6871882 ],
#         [0.8300751 ],
#         [0.97949815],
#         [1.1305318 ],
#         [1.2781801 ]],
#
#        [[0.06114408],
#         [0.11259096],
#         [0.17458642],
#         [0.24930449],
#         [0.3385187 ],
#         [0.44306847],
#         [0.56259894],
#         [0.6954127 ],
#         [0.8384833 ],
#         [0.9876816 ],
#         [1.1381603 ],
#         [1.2850482 ]],
#
#        [[0.06133008],
#         [0.1133209 ],
#         [0.17610571],
#         [0.25167337],
#         [0.34145018],
#         [0.44605267],
#         [0.5650781 ],
#         [0.6969493 ],
#         [0.83886534],
#         [0.9868619 ],
#         [1.1362643 ],
#         [1.2823642 ]],
#
#        [[0.06127775],
#         [0.11287711],
#         [0.17464383],
#         [0.24820851],
#         [0.3348448 ],
#         [0.43527648],
#         [0.5494626 ],
#         [0.67637223],
#         [0.8137322 ],
#         [0.9580936 ],
#         [1.1051986 ],
#         [1.2506161 ]]], dtype=float32)

# %%
# data_y_test[-10:,0]

# %%
# data_x_test[-10:,0,-1]

# %%
# t = []
# for i in range(2000):
#     if data_y_test[:,0][i]>data_x_test[:,0,-1][i]:
#         t.append(1)
#     else:
#         t.append(0)
# len(t)

# %%
# p = []
# for i in range(2000):
#     if y_pred[:,0][i]>data_x_test[:,0,-1][i]:
#         p.append(1)
#     else:
#         p.append(0)
# len(p)

# %%
# n = 0
# for i in range(2000):
#     if t[i]==p[i]:
#         n=n+1
# n/2000

# %%
data_y_test
# Out:
# array([[[0.72106599],
#         [0.5782126 ],
#         [0.65889306],
#         [0.65519955],
#         [0.64346259],
#         [0.59414036],
#         [0.659587  ],
#         [0.76035414],
#         [0.67878347],
#         [0.44318469],
#         [0.52934327],
#         [0.42829165]],
#
#        [[0.5782126 ],
#         [0.65889306],
#         [0.65519955],
#         [0.64346259],
#         [0.59414036],
#         [0.659587  ],
#         [0.76035414],
#         [0.67878347],
#         [0.44318469],
#         [0.52934327],
#         [0.42829165],
#         [0.41449752]],
#
#        [[0.65889306],
#         [0.65519955],
#         [0.64346259],
#         [0.59414036],
#         [0.659587  ],
#         [0.76035414],
#         [0.67878347],
#         [0.44318469],
#         [0.52934327],
#         [0.42829165],
#         [0.41449752],
#         [0.47848904]],
#
#        [[0.65519955],
#         [0.64346259],
#         [0.59414036],
#         [0.659587  ],
#         [0.76035414],
#         [0.67878347],
#         [0.44318469],
#         [0.52934327],
#         [0.42829165],
#         [0.41449752],
#         [0.47848904],
#         [0.92764034],
#         [0.86035021],
#         [0.58780241],
#         [0.62685057],
#         [0.4563786 ],
#         [0.5665696 ],
#         [0.62248538],
#         [0.67331531],
#         [0.70547672]],
#
#        [[0.60761336],
#         [0.68724203],
#         [0.92764034],
#         [0.86035021],
#         [0.58780241],
#         [0.62685057],
#         [0.4563786 ],
#         [0.5665696 ],
#         [0.62248538],
#         [0.67331531],
#         [0.70547672],
#         [0.62259383]],
#
#        [[0.68724203],
#         [0.92764034],
#         [0.86035021],
#         [0.58780241],
#         [0.62685057],
#         [0.4563786 ],
#         [0.5665696 ],
#         [0.62248538],
#         [0.67331531],
#         [0.70547672],
#         [0.62259383],
#         [0.66968399]],
#
#        [[0.92764034],
#         [0.86035021],
#         [0.58780241],
#         [0.62685057],
#         [0.4563786 ],
#         [0.5665696 ],
#         [0.62248538],
#         [0.67331531],
#         [0.70547672],
#         [0.62259383],
#         [0.66968399],
#         [0.72938174]],
#
#        [[0.86035021],
#         [0.58780241],
#         [0.62685057],
#         [0.4563786 ],
#         [0.5665696 ],
#         [0.62248538],
#         [0.67331531],
#         [0.70547672],
#         [0.62259383],
#         [0.66968399],
#         [0.72938174],
#         [0.86360998]],
#
#        [[0.58780241],
#         [0.62685057],
#         [0.4563786 ],
#         [0.5665696 ],
#         [0.62248538],
#         [0.67331531],
#         [0.70547672],
#         [0.62259383],
#         [0.66968399],
#         [0.72938174],
#         [0.86360998],
#         [0.89133784]],
#
#        [[0.62685057],
#         [0.4563786 ],
#         [0.5665696 ],
#         [0.62248538],
#         [0.67331531],
#         [0.70547672],
#         [0.62259383],
#         [0.66968399],
#         [0.72938174],
#         [0.86360998],
#         [0.89133784],
#         [0.65131148]],
#
#        [[0.4563786 ],
#         [0.5665696 ],
#         [0.62248538],
#         [0.67331531],
#         [0.70547672],
#         [0.62259383],
#         [0.66968399],
#         [0.72938174],
#         [0.86360998],
#         [0.89133784],
#         [0.65131148],
#         [0.72744386]],
#
#        [[0.5665696 ],
#         [0.62248538],
#         [0.67331531],
#         [0.70547672],
#         [0.62259383],
#         [0.66968399],
#         [0.72938174],
#         [0.86360998],
#         [0.89133784],
#         [0.65131148],
#         [0.72744386],
#         [0.64434565]],
#
#        [[0.62248538],
#         [0.67331531],
#         [0.70547672],
#         [0.62259383],
#         [0.66968399],
#         [0.72938174],
#         [0.86360998],
#         [0.89133784],
#         [0.65131148],
#         [0.72744386],
#         [0.64434565],
#         [0.60235209]],
#
#        [[0.67331531],
#         [0.70547672],
#         [0.62259383],
#         [0.66968399],
#         [0.72938174],
#         [0.86360998],
#         [0.89133784],
#         [0.65131148],
#         [0.72744386],
#         [0.64434565],
#         [0.60235209],
#         [0.57779921]],
#
#        [[0.70547672],
#         [0.62259383],
#         [0.66968399],
#         [0.72938174],
#         [0.86360998],
#         [0.89133784],
#         [0.65131148],
#         [0.72744386],
#         [0.64434565],
#         [0.60235209],
#         [0.57779921],
#         [0.68251193]],
#
#        [[0.62259383],
#         [0.66968399],
#         [0.72938174],
#         [0.86360998],
#         [0.89133784],
#         [0.65131148],
#         [0.72744386],
#         [0.64434565],
#         [0.60235209],
#         [0.57779921],
#         [0.68251193],
#         [0.65858912]],
#
#        [[0.66968399],
#         [0.72938174],
#         [0.86360998],
#         [0.89133784],
#         [0.65131148],
#         [0.72744386],
#         [0.64434565],
#         [0.60235209],
#         [0.57779921],
#         [0.68251193],
#         [0.65858912],
#         [0.60869866]],
#
#        [[0.72938174],
#         [0.86360998],
#         [0.89133784],
#         [0.65131148],
#         [0.72744386],
#         [0.64434565],
#         [0.60235209],
#         [0.57779921],
#         [0.68251193],
#         [0.65858912],
#         [0.60869866],
#         [0.55625664]],
#
#        [[0.86360998],
#         [0.89133784],
#         [0.65131148],
#         [0.72744386],
#         [0.64434565],
#         [0.60235209],
#         [0.57779921],
#         [0.68251193],
#         [0.65858912],
#         [0.60869866],
#         [0.55625664],
#         [0.65306548]],
#
#        [[0.89133784],
#         [0.65131148],
#         [0.72744386],
#         [0.64434565],
#         [0.60235209],
#         [0.57779921],
#         [0.68251193],
#         [0.65858912],
#         [0.60869866],
#         [0.55625664],
#         [0.65306548],
#         [0.65942727]]])

# %%
data_max = np.max(data_origin)
data_min = np.min(data_origin)
y_pred_to_origin = []
for i in y_pred.reshape(396):
    y = i*(data_max - data_min) + data_min
    y_pred_to_origin.append(y)

# %%
len(y_pred_to_origin)
# Out:
# 396

# %%
y_pred_to_origin = np.array(y_pred_to_origin).reshape(33,12,1)

# %%
y_pred_to_origin
# Out:
# array([[[12.17221342],
#         [12.93771316],
#         [13.84878902],
#         [14.93154974],
#         [16.20833707],
#         [17.69326156],
#         [19.38639378],
#         [21.27035252],
#         [23.30838328],
#         [25.44455647],
#         [27.61101481],
#         [29.73875329]],
#
#        [[12.17224881],
#         [12.93785148],
#         [13.84908264],
#         [14.93129118],
#         [16.2062132 ],
#         [17.68651218],
#         [19.37173752],
#         [21.24446873],
#         [23.26699744],
#         [25.38433274],
#         [27.53179421],
#         [29.64498539]],
#
#        [[12.17223853],
#         [12.93777233],
#         [13.84813301],
#         [14.92807569],
#         [16.19790353],
#         [17.6696749 ],
#         [19.34275725],
#         [21.1985324 ],
#         [23.19997699],
#         [25.29531451],
#         [27.42499019],
#         [29.52678504]],
#
#        [[12.1722046 ],
#         [12.93697108],
#         [13.84525223],
#         [14.92037937],
#         [16.18195848],
#         [17.64168556],
#         [19.2974461 ],
#         [21.13091712],
#         [23.1080793 ],
#         [25.18255779],
#         [27.29756917],
#         [29.39293527]],
#
#        [[12.17157996],
#         [12.93457593],
#         [13.83859796],
#         [14.90627372],
#         [16.15675079],
#         [17.60002954],
#         [19.23386688],
#         [21.04251604],
#         [22.99725978],
#         [25.05477326],
#         [27.16086675],
#         [29.25623106]],
#
#        [[12.17180213],
#         [12.9345526 ],
#         [13.83750723],
#         [14.90284924],
#         [16.14769088],
#         [17.58107689],
#         [19.20215721],
#         [20.99926803],
#         [22.9457387 ],
#         [25.00019143],
#         [27.10915454],
#         [29.21263919]],
#
#        [[12.17089125],
#         [12.93127102],
#         [13.82984395],
#         [14.88677782],
#         [16.11822654],
#
#        [[12.17558386],
#         [12.95462624],
#         [13.89540815],
#         [15.02773132],
#         [16.37296765],
#         [17.94035526],
#         [19.72385924],
#         [21.69984785],
#         [23.82635024],
#         [26.04396436],
#         [28.28264473],
#         [30.47183946]],
#
#        [[12.17479981],
#         [12.94797634],
#         [13.87350303],
#         [14.97581302],
#         [16.27399103],
#         [17.77888233],
#         [19.48987357],
#         [21.39151628],
#         [23.44974962],
#         [25.61289355],
#         [27.81714913],
#         [29.99611753]]])

# %%
data_y_test = []
for r in range(12,145):
    for c in range(12):
        item = []
        item.append(data_origin[r+c])
        data_y_test.append(item)
data_y_test = np.array(data_y_test)
print(data_y_test)
print(data_y_test.shape)
# Out:
# [[14.25003836]
#  [12.63311045]
#  [13.46243023]
#  ...
#  [19.59167681]
#  [21.04228263]
#  [21.13760913]]
# (1596, 1)

# %%
data_y_test = data_y_test.reshape(133,12,1)[-33:,:]

# %%
data_y_test
# Out:
# array([[[22.06121774],
#         [19.92066993],
#         [21.12960442],
#         [21.07426005],
#         [20.89839063],
#         [20.15933505],
#         [21.14000262],
#         [22.6499205 ],
#         [21.42764687],
#         [17.89738074],
#         [19.18840066],
#         [17.67422009]],
#
#        [[19.92066993],
#         [21.12960442],
#         [21.07426005],
#         [20.89839063],
#         [20.15933505],
#         [21.14000262],
#         [22.6499205 ],
#         [21.42764687],
#         [17.89738074],
#         [19.18840066],
#         [17.67422009],
#         [17.4675257 ]],
#
#        [[21.12960442],
#         [21.07426005],
#         [20.89839063],
#         [20.15933505],
#         [21.14000262],
#         [22.6499205 ],
#         [21.42764687],
#         [17.89738074],
#         [19.18840066],
#         [17.67422009],
#         [17.4675257 ],
#         [18.42638918]],
#
#        [[21.07426005],
#         [20.89839063],
#         [20.15933505],
#         [21.14000262],
#         [22.6499205 ],
#         [21.42764687],
#         [17.89738074],
#         [19.18840066],
#         [17.67422009],
#         [17.4675257 ],
#         [18.42638918],
#         [19.08247928]],
#
#        [[20.89839063],
#         [20.15933505],
#         [21.14000262],
#         [22.6499205 ],
#         [21.42764687],
#         [17.89738074],
#         [19.18840066],
#         [17.67422009],
#         [17.4675257 ],
#         [18.42638918],
#         [19.08247928],
#         [19.73316095]],
#
#        [[20.15933505],
#         [21.14000262],
#         [22.6499205 ],
#         [21.42764687],
#         [17.89738074],
#         [19.18840066],
#         [17.67422009],
#         [17.4675257 ],
#         [18.42638918],
#         [19.08247928],
#         [19.73316095],
#         [18.68432664]],
#
#        [[21.14000262],
#         [22.6499205 ],
#         [21.42764687],
#         [17.89738074],
#         [19.18840066],
#         [17.67422009],
#         [17.4675257 ],
#         [18.42638918],
#         [19.08247928],
#         [19.73316095],
#         [18.68432664],
#         [20.36121768]],
#
#        [[22.6499205 ],
#         [21.42764687],
#         [17.89738074],
#         [19.18840066],
#         [17.67422009],
#         [17.4675257 ],
#         [18.42638918],
#         [19.08247928],
#         [19.73316095],
#         [18.68432664],
#         [20.36121768],
#         [21.55439184]],
#
#        [[21.42764687],
#         [17.89738074],
#         [19.18840066],
#         [17.67422009],
#         [17.4675257 ],
#         [18.42638918],
#         [19.08247928],
#         [19.73316095],
#         [18.68432664],
#         [20.36121768],
#         [21.55439184],
#         [25.15657524]],
#
#        [[17.89738074],
#         [19.18840066],
#         [17.67422009],
#         [17.4675257 ],
#         [18.42638918],
#         [19.08247928],
#         [19.73316095],
#         [18.68432664],
#         [20.36121768],
#         [21.55439184],
#         [25.15657524],
#         [24.1482845 ]],
#
#        [[19.18840066],
#         [17.67422009],
#         [17.4675257 ],
#         [18.42638918],
#         [19.08247928],
#         [19.73316095],
#         [18.68432664],
#         [20.36121768],
#         [21.55439184],
#         [25.15657524],
#         [24.1482845 ],
#         [20.06436585]],
#
#        [[17.67422009],
#         [17.4675257 ],
#         [18.42638918],
#         [19.08247928],
#         [19.73316095],
#         [18.68432664],
#         [20.36121768],
#         [21.55439184],
#         [25.15657524],
#         [24.1482845 ],
#         [20.06436585],
#         [20.64947237]],
#
#        [[17.4675257 ],
#         [18.42638918],
#         [19.08247928],
#         [19.73316095],
#         [18.68432664],
#         [20.36121768],
#         [21.55439184],
#         [25.15657524],
#         [24.1482845 ],
#         [20.06436585],
#         [20.64947237],
#         [18.09508135]],
#
#        [[18.42638918],
#         [19.08247928],
#         [19.73316095],
#         [18.68432664],
#         [20.36121768],
#         [21.55439184],
#         [25.15657524],
#         [24.1482845 ],
#         [20.06436585],
#         [20.64947237],
#         [18.09508135],
#         [19.74620851]],
#
#        [[19.08247928],
#         [19.73316095],
#         [18.68432664],
#         [20.36121768],
#         [21.55439184],
#         [25.15657524],
#         [24.1482845 ],
#         [20.06436585],
#         [20.64947237],
#         [18.09508135],
#         [19.74620851],
#         [20.58406331]],
#
#        [[19.73316095],
#         [18.68432664],
#         [20.36121768],
#         [21.55439184],
#         [25.15657524],
#         [24.1482845 ],
#         [20.06436585],
#         [20.64947237],
#         [18.09508135],
#         [19.74620851],
#         [20.58406331],
#         [21.34571071]],
#
#        [[18.68432664],
#         [20.36121768],
#         [21.55439184],
#         [25.15657524],
#         [24.1482845 ],
#         [20.06436585],
#         [20.64947237],
#         [18.09508135],
#         [19.74620851],
#         [20.58406331],
#         [21.34571071],
#         [21.82762467]],
#
#        [[20.36121768],
#         [21.55439184],
#         [25.15657524],
#         [24.1482845 ],
#         [20.06436585],
#         [20.64947237],
#         [18.09508135],
#         [19.74620851],
#         [20.58406331],
#         [21.34571071],
#         [21.82762467],
#         [20.58568844]],
#
#        [[21.55439184],
#         [25.15657524],
#         [24.1482845 ],
#         [20.06436585],
#         [20.64947237],
#         [18.09508135],
#         [19.74620851],
#         [20.58406331],
#         [21.34571071],
#         [21.82762467],
#         [20.58568844],
#         [21.29129811]],
#
#        [[25.15657524],
#         [24.1482845 ],
#         [20.06436585],
#         [20.64947237],
#         [18.09508135],
#         [19.74620851],
#         [20.58406331],
#         [21.34571071],
#         [21.82762467],
#         [20.58568844],
#         [21.29129811],
#         [22.18582289]],
#
#        [[24.1482845 ],
#         [20.06436585],
#         [20.64947237],
#         [18.09508135],
#         [19.74620851],
#         [20.58406331],
#         [21.34571071],
