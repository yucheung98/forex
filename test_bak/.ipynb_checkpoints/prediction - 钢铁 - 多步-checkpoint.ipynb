# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
from sklearn import preprocessing
from keras.layers.core import Dense, Activation, Dropout
from keras.layers.recurrent import LSTM
from keras.models import Sequential
from keras import metrics

# %%
data_xls = pd.read_excel('辽宁钢铁行业月用电量.xls')

# %%
data_xls
# Out:
#           月份  辽宁钢铁行业月用电量（亿千万时）
# 0    2007M01         13.856687
# 1    2007M02         11.941298
# 2    2007M03         14.555307
# 3    2007M04         13.656541
# 4    2007M05         13.143799
# ..       ...               ...
# 153  2019M10         19.591677
# 154  2019M11         21.042283
# 155  2019M12         21.137609
# 156  2020M01         22.502425
# 157  2020M02         19.675281
#
# [158 rows x 2 columns]

# %%
data_xls.drop(['月份'], axis=1, inplace=True)
data_xls
# Out:
#      辽宁钢铁行业月用电量（亿千万时）
# 0           13.856687
# 1           11.941298
# 2           14.555307
# 3           13.656541
# 4           13.143799
# ..                ...
# 153         19.591677
# 154         21.042283
# 155         21.137609
# 156         22.502425
# 157         19.675281
#
# [158 rows x 1 columns]

# %%
# #Max-Min标准化
# #建立MinMaxScaler对象
scaler = preprocessing.MinMaxScaler()

# # 标准化处理
# scaler = preprocessing.StandardScaler()

data = scaler.fit_transform(data_xls)
# data = np.array(data_xls)
data
# Out:
# array([[0.17352158],
#        [0.04569457],
#        [0.22014526],
#        [0.16016446],
#        [0.12594572],
#        [0.17623064],
#        [0.17108138],
#        [0.16946594],
#        [0.18185039],
#        [0.13476088],
#        [0.18095552],
#        [0.20192803],
#        [0.19977261],
#        [0.09186396],
#        [0.14721013],
#        [0.09405303],
#        [0.29979003],
#        [0.18065369],
#        [0.18583854],
#        [0.23212666],
#        [0.21184646],
#        [0.12102172],
#        [0.        ],
#        [0.10010754],
#        [0.26186207],
#        [0.14140224],
#        [0.23200236],
#        [0.30190857],
#        [0.43137439],
#        [0.43901368],
#        [0.48901056],
#        [0.59532138],
#        [0.45639647],
#        [0.5004796 ],
#        [0.46555455],
#        [0.54568012],
#        [0.66581344],
#        [0.32581249],
#        [0.51821492],
#        [0.5203929 ],
#        [0.56260374],
#        [0.57005162],
#        [0.54822271],
#        [0.67233969],
#        [0.69445304],
#        [0.68755161],
#        [0.70105322],
#        [0.67174946],
#        [0.84251424],
#        [0.60820288],
#        [0.75503041],
#        [0.73776892],
#        [0.81455859],
#        [0.78684662],
#        [0.82959787],
#        [0.79837883],
#        [0.73975918],
#        [0.75568395],
#        [0.63540444],
#        [0.692194  ],
#        [0.62393688],
#        [0.5248018 ],
#        [0.70620392],
#        [0.71930169],
#        [0.78155148],
#        [0.71689779],
#        [0.90603019],
#        [0.69171976],
#        [0.60203875],
#        [0.75916102],
#        [0.79539194],
#        [0.80755584],
#        [0.8137116 ],
#        [0.58721189],
#        [0.7769315 ],
#        [0.84664932],
#        [0.89263423],
#        [0.80717932],
#        [0.93825809],
#        [1.        ],
#        [0.97295553],
#        [0.85100013],
#        [0.77175535],
#        [0.83979129],
#        [0.79258752],
#        [0.56835198],
#        [0.74762213],
#        [0.85193598],
#        [0.99793644],
#        [0.89024074],
#        [0.94805902],
#        [0.93348947],
#        [0.7942554 ],
#        [0.686503  ],
#        [0.69641676],
#        [0.66722556],
#        [0.63927665],
#        [0.44713635],
#        [0.55365841],
#        [0.6434521 ],
#        [0.63649924],
#        [0.63958462],
#        [0.63868725],
#        [0.63572763],
#        [0.58122482],
#        [0.60062986],
#        [0.52094097],
#        [0.56675305],
#        [0.54238029],
#        [0.41565319],
#        [0.48999128],
#        [0.59021031],
#        [0.72106599],
#        [0.5782126 ],
#        [0.65889306],
#        [0.65519955],
#        [0.64346259],
#        [0.59414036],
#        [0.659587  ],
#        [0.76035414],
#        [0.67878347],
#        [0.44318469],
#        [0.52934327],
#        [0.42829165],
#        [0.41449752],
#        [0.47848904],
#        [0.52227441],
#        [0.56569885],
#        [0.49570297],
#        [0.60761336],
#        [0.68724203],
#        [0.92764034],
#        [0.86035021],
#        [0.58780241],
#        [0.62685057],
#        [0.4563786 ],
#        [0.5665696 ],
#        [0.62248538],
#        [0.67331531],
#        [0.70547672],
#        [0.62259383],
#        [0.66968399],
#        [0.72938174],
#        [0.86360998],
#        [0.89133784],
#        [0.65131148],
#        [0.72744386],
#        [0.64434565],
#        [0.60235209],
#        [0.57779921],
#        [0.68251193],
#        [0.65858912],
#        [0.60869866],
#        [0.55625664],
#        [0.65306548],
#        [0.65942727],
#        [0.75051079],
#        [0.56183609]])

# %%
data.shape
# Out:
# (158, 1)

# %%
data = data[:156,:]

# %%
data.shape
# Out:
# (156, 1)

# %%
# n = 0
# for i in range(data.shape[0]):
#     if data[i,0]<0:
#         n=n+1
# print(n)

# %%
# data_y = data[-146:-2,:]
# print(data_y.shape)

# %%
data_x = []
for r in range(133):
    for c in range(12):
        item = []
        item.append(data[r+c, 0])
        data_x.append(item)
data_x = np.array(data_x)
print(data_x)
print(data_x.shape)
# Out:
# [[0.17352158]
#  [0.04569457]
#  [0.22014526]
#  ...
#  [0.66968399]
#  [0.72938174]
#  [0.86360998]]
# (1596, 1)

# %%
data_x=data_x.reshape(133,12,1)

# %%
data_x.shape
# Out:
# (133, 12, 1)

# %%
data_x
# Out:
# array([[[0.17352158],
#         [0.04569457],
#         [0.22014526],
#         ...,
#         [0.13476088],
#         [0.18095552],
#         [0.20192803]],
#
#        [[0.04569457],
#         [0.22014526],
#         [0.16016446],
#         ...,
#         [0.18095552],
#         [0.20192803],
#         [0.19977261]],
#
#        [[0.22014526],
#         [0.16016446],
#         [0.12594572],
#         ...,
#         [0.20192803],
#         [0.19977261],
#         [0.09186396]],
#
#        ...,
#
#        [[0.68724203],
#         [0.92764034],
#         [0.86035021],
#         ...,
#         [0.70547672],
#         [0.62259383],
#         [0.66968399]],
#
#        [[0.92764034],
#         [0.86035021],
#         [0.58780241],
#         ...,
#         [0.62259383],
#         [0.66968399],
#         [0.72938174]],
#
#        [[0.86035021],
#         [0.58780241],
#         [0.62685057],
#         ...,
#         [0.66968399],
#         [0.72938174],
#         [0.86360998]]])

# %%
data_y = []
for r in range(12,145):
    for c in range(12):
        item = []
        item.append(data[r+c, 0])
        data_y.append(item)
data_y = np.array(data_y)
print(data_y)
print(data_y.shape)
# Out:
# [[0.19977261]
#  [0.09186396]
#  [0.14721013]
#  ...
#  [0.55625664]
#  [0.65306548]
#  [0.65942727]]
# (1596, 1)

# %%
data_y = data_y.reshape(133,12,1)

# %%
data_y
# Out:
# array([[[0.19977261],
#         [0.09186396],
#         [0.14721013],
#         ...,
#         [0.12102172],
#         [0.        ],
#         [0.10010754]],
#
#        [[0.09186396],
#         [0.14721013],
#         [0.09405303],
#         ...,
#         [0.        ],
#         [0.10010754],
#         [0.26186207]],
#
#        [[0.14721013],
#         [0.09405303],
#         [0.29979003],
#         ...,
#         [0.10010754],
#         [0.26186207],
#         [0.14140224]],
#
#        ...,
#
#        [[0.72938174],
#         [0.86360998],
#         [0.89133784],
#         ...,
#         [0.65858912],
#         [0.60869866],
#         [0.55625664]],
#
#        [[0.86360998],
#         [0.89133784],
#         [0.65131148],
#         ...,
#         [0.60869866],
#         [0.55625664],
#         [0.65306548]],
#
#        [[0.89133784],
#         [0.65131148],
#         [0.72744386],
#         ...,
#         [0.55625664],
#         [0.65306548],
#         [0.65942727]]])

# %%
data_x_train = data_x[:100,:, :]
data_y_train = data_y[:100,:,:]

data_x_test = data_x[-33:,:, :]
data_y_test = data_y[-33:,:,:]

# %%
print(data_x_train.shape)
print(data_y_test.shape)
print(data_x_train.shape)
print(data_y_test.shape)
# Out:
# (100, 12, 1)
# (33, 12, 1)
# (100, 12, 1)
# (33, 12, 1)

# %%
#     model = Sequential()
 
#     model.add(LSTM(input_dim=10,output_dim=128,return_sequences=True))
#     model.add(Dropout(0.1))
 
#     model.add(LSTM(128,return_sequences=False))
#     model.add(Dropout(0.1))
 
#     model.add(Dense(output_dim=1))
#     model.add(Activation("linear"))
 
#     model.compile(loss="mse", optimizer="rmsprop")

# %%
# model = Sequential()

# model.add(LSTM(output_dim=128, 
#                 input_shape=(10, 1),
#                 activation='relu',
#                 return_sequences=True))
# for i in range(6):
#     model.add(LSTM(output_dim=128,
#                     activation='tanh',
#                     return_sequences=True))
# #     model.add(Dropout(0.1))

# model.add(LSTM(output_dim=1,
#                activation='linear',
#                return_sequences=False))

# model.compile(loss='mse', optimizer='adam', metrics=[metrics.mse])
# model.summary()

# %%
def create_model(output_dim1, num_layer, output_dim2):
    model = Sequential()

    model.add(LSTM(output_dim=output_dim1, 
                input_shape=(12, 1),
                activation='relu',
                return_sequences=True))
    for i in range(num_layer):
        model.add(LSTM(output_dim=output_dim2,
                        activation='tanh',
                        return_sequences=True))
#     model.add(Dropout(0.1))

    model.add(Dense(output_dim=1,
               activation='linear'))

    model.compile(loss='mse', optimizer='adam', metrics=[metrics.mse])
#     model.summary()
    return model

# %%
# from sklearn.model_selection import RandomizedSearchCV
# from skopt.space import Real, Categorical, Integer
# from keras.wrappers.scikit_learn import KerasRegressor
# from sklearn.model_selection import train_test_split

# %%
# #采用暴力搜索，所有参数进行组合，然后选择最好的参数
# tuned_parameters=[{'output_dim1':Integer(28, 128),
#                    'num_layer':Integer(3,12),
#                    'output_dim2':Integer(28, 128)}]
# # 'output_dim1':Integer(28, 128),
# #             'num_layer':Integer(3,12),
# #             'output_dim2':Integer(28, 128)

# %%
# train_x, test_x, train_y, test_y = train_test_split(data_x, data_y, train_size=0.80, random_state=0)

# %%
# model=KerasRegressor(build_fn=create_model)

# %%
# #采用随机搜索，给参数一个范围，然后系统随机选择参数，进行检验，然后选择最好的
# tuned_parameters={'output_dim1':[28, 64, 96,128],
#                    'num_layer':[4,5,6,7,8],
#                    'output_dim2':[28,64, 96,128]}

# lstm=RandomizedSearchCV(model,tuned_parameters,scoring='neg_mean_squared_error',n_iter=10)
 
# lstm.fit(data_x_train,data_y_train)

# %%
# print('最优训练器:',lstm.best_estimator_)
# print('最优训练器的精度:',lstm.best_score_)

# %%
# best_estimator_ = lstm.best_estimator_

# %%
# best_estimator_.predict(data_x_test,batch_size = 1)

# %%
# import sklearn
# sorted(sklearn.metrics.SCORERS.keys())

# %%
# from sklearn.model_selection import train_test_split
# from skopt import BayesSearchCV
# from skopt.space import Real, Categorical, Integer

# %%
# class FixedBayesSearchCV(BayesSearchCV):
#     """
#     Dirty hack to avoid compatibility issues with sklearn 0.2 and skopt.
#     Credit: https://www.kaggle.com/c/home-credit-default-risk/discussion/64004
#     For context, on why the workaround see:
#         - https://github.com/scikit-optimize/scikit-optimize/issues/718
#         - https://github.com/scikit-optimize/scikit-optimize/issues/762
#     """
#     def __init__(self, estimator, search_spaces, optimizer_kwargs=None,
#                 n_iter=50, scoring=None, fit_params=None, n_jobs=1,
#                 n_points=1, iid=True, refit=True, cv=None, verbose=0,
#                 pre_dispatch='2*n_jobs', random_state=None,
#                 error_score='raise', return_train_score=False):
#         """
#         See: https://github.com/scikit-optimize/scikit-optimize/issues/762#issuecomment-493689266
#         """
 
#         # Bug fix: Added this line
#         self.fit_params = fit_params
 
#         self.search_spaces = search_spaces
#         self.n_iter = n_iter
#         self.n_points = n_points
#         self.random_state = random_state
#         self.optimizer_kwargs = optimizer_kwargs
#         self._check_search_space(self.search_spaces)
 
#         # Removed the passing of fit_params to the parent class.
#         super(BayesSearchCV, self).__init__(
#                 estimator=estimator, scoring=scoring, n_jobs=n_jobs, iid=iid,
#                 refit=refit, cv=cv, verbose=verbose, pre_dispatch=pre_dispatch,
#                 error_score=error_score, return_train_score=return_train_score)
 
#     def _run_search(self, x):
#         raise BaseException('Use newer skopt')

# %%
# def lstm_auto_para_tuning_bayesian(model,data_x,data_y):
#     train_x, test_x, train_y, test_y = train_test_split(data_x, data_y, train_size=0.80, random_state=0)
#     # cv：交叉验证 n_points：并行采样的超参组数
#     opt = FixedBayesSearchCV(model,cv=5,n_points=2,n_jobs=4,verbose=1,
#         search_spaces={
#             'output_dim1':Integer(28, 128),
#             'num_layer':Integer(3,12),
#             'output_dim2':Integer(28, 128)
#         },
#          fit_params={
#                  'eval_set':[(test_x, test_y)],
#                  'eval_metric': 'mse',
#                  'early_stopping_rounds': 50
#                  })
#     opt.fit(train_x,train_y)
#     print("val. score: %s" % opt.best_score_)
#     print("test score: %s" % opt.score(test_x, test_y))
#     print("Best parameters: ", opt.best_params_)
#     print("Best estimator:", opt.best_estimator_)

# %%
model = create_model(32, 4, 32)
# Out:
# e:\envs\python36env\lib\site-packages\ipykernel_launcher.py:7: UserWarning: Update your `LSTM` call to the Keras 2 API: `LSTM(input_shape=(12, 1), activation="relu", return_sequences=True, units=32)`
#   import sys
# e:\envs\python36env\lib\site-packages\ipykernel_launcher.py:11: UserWarning: Update your `LSTM` call to the Keras 2 API: `LSTM(activation="tanh", return_sequences=True, units=32)`
#   # This is added back by InteractiveShellApp.init_path()
# e:\envs\python36env\lib\site-packages\ipykernel_launcher.py:15: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="linear", units=1)`
#   from ipykernel import kernelapp as app

# %%
# lstm_auto_para_tuning_bayesian(model,data_x,data_y)

# %%
model.fit(data_x_train, data_y_train, epochs=20, batch_size=100, verbose=1)
# Out:
# WARNING:tensorflow:From e:\envs\python36env\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/20
# 100/100 [==============================] - 10s 102ms/step - loss: 0.4386 - mean_squared_error: 0.4386
# Epoch 2/20
# 100/100 [==============================] - 0s 1ms/step - loss: 0.4279 - mean_squared_error: 0.4279
# Epoch 3/20
# 100/100 [==============================] - 0s 990us/step - loss: 0.4168 - mean_squared_error: 0.4168
# Epoch 4/20
# 100/100 [==============================] - 0s 920us/step - loss: 0.4050 - mean_squared_error: 0.4050
# Epoch 5/20
# 100/100 [==============================] - 0s 990us/step - loss: 0.3924 - mean_squared_error: 0.3924
# Epoch 6/20
# 100/100 [==============================] - 0s 870us/step - loss: 0.3787 - mean_squared_error: 0.3787
# Epoch 7/20
# 100/100 [==============================] - 0s 910us/step - loss: 0.3639 - mean_squared_error: 0.3639
# Epoch 8/20
# 100/100 [==============================] - 0s 900us/step - loss: 0.3477 - mean_squared_error: 0.3477
# Epoch 9/20
# 100/100 [==============================] - 0s 979us/step - loss: 0.3301 - mean_squared_error: 0.3301
# Epoch 10/20
# 100/100 [==============================] - 0s 880us/step - loss: 0.3109 - mean_squared_error: 0.3109
# Epoch 11/20
# 100/100 [==============================] - 0s 869us/step - loss: 0.2902 - mean_squared_error: 0.2902
# Epoch 12/20
# 100/100 [==============================] - 0s 920us/step - loss: 0.2679 - mean_squared_error: 0.2679
# Epoch 13/20
# 100/100 [==============================] - 0s 900us/step - loss: 0.2443 - mean_squared_error: 0.2443
# Epoch 14/20
# 100/100 [==============================] - 0s 891us/step - loss: 0.2197 - mean_squared_error: 0.2197
# Epoch 15/20
# 100/100 [==============================] - 0s 930us/step - loss: 0.1953 - mean_squared_error: 0.1953
# Epoch 16/20
# 100/100 [==============================] - 0s 900us/step - loss: 0.1731 - mean_squared_error: 0.1731
# Epoch 17/20
# 100/100 [==============================] - 0s 892us/step - loss: 0.1561 - mean_squared_error: 0.1561
# Epoch 18/20
# 100/100 [==============================] - 0s 882us/step - loss: 0.1496 - mean_squared_error: 0.1496
# Epoch 19/20
# 100/100 [==============================] - 0s 920us/step - loss: 0.1561 - mean_squared_error: 0.1561
# Epoch 20/20
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1668 - mean_squared_error: 0.1668

# %%
# 评估模型,不输出预测结果
loss,accuracy = model.evaluate(data_x_test,data_y_test)
print('\ntest loss','{:.5f}'.format(loss))
print('accuracy','{:.5f}'.format(accuracy))
# Out:
# 33/33 [==============================] - 2s 57ms/step
#
# test loss 0.16347
# accuracy 0.16347

# %%
y_pred = model.predict(data_x_test,batch_size = 1)

# %%
y_pred
# Out:
# array([[[0.06368694],
#         [0.11673226],
#         [0.17928758],
#         [0.2526052 ],
#         [0.33774295],
#         [0.43540657],
#         [0.54572445],
#         [0.6681188 ],
#         [0.80119306],
#         [0.94264024],
#         [1.0894089 ],
#         [1.2380376 ]],
#
#        [[0.06368862],
#         [0.11673883],
#         [0.17930143],
#         [0.25259092],
#         [0.33763546],
#         [0.43506643],
#         [0.54497886],
#         [0.6667767 ],
#         [0.7989932 ],
#         [0.93933254],
#         [1.0848731 ],
#         [1.2323921 ]],
#
#        [[0.06368813],
#         [0.11673501],
#         [0.17925467],
#         [0.25243247],
#         [0.3372238 ],
#         [0.43422487],
#         [0.5435086 ],
#         [0.6643999 ],
#         [0.79543215],
#         [0.9344335 ],
#         [1.07873   ],
#         [1.2252418 ]],
#
#        [[0.06368651],
#         [0.11669617],
#         [0.17911552],
#         [0.25205904],
#         [0.3364446 ],
#         [0.43284127],
#         [0.5412339 ],
#         [0.6609334 ],
#         [0.79058444],
#         [0.9282619 ],
#         [1.0714419 ],
#         [1.2171888 ]],
#
#        [[0.06365681],
#         [0.11658284],
#         [0.17879857],
#         [0.25138268],
#         [0.33522472],
#         [0.4308004 ],
#         [0.53806734],
#         [0.6564318 ],
#         [0.7847737 ],
#         [0.92131436],
#         [1.0636808 ],
#         [1.2090342 ]],
#
#        [[0.06366736],
#         [0.11658067],
#         [0.1787443 ],
#         [0.2512153 ],
#         [0.33478323],
#         [0.4298723 ],
#         [0.53649527],
#         [0.6542452 ],
#         [0.7820987 ],
#         [0.91838306],
#         [1.060789  ],
#         [1.2064823 ]],
#
#        [[0.06362418],
#         [0.11642607],
#         [0.17838307],
#         [0.25045276],
#         [0.33337387],
#         [0.42762598],
#         [0.533413  ],
#         [0.6504356 ],
#         [0.7777929 ],
#         [0.91389865],
#         [1.0564731 ],
#         [1.2026279 ]],
#
#        [[0.06364896],
#         [0.1165159 ],
#         [0.17850891],
#         [0.2505436 ],
#         [0.3334015 ],
#         [0.42772147],
#         [0.5337698 ],
#         [0.6513129 ],
#         [0.77947426],
#         [0.9166344 ],
#         [1.0604016 ],
#         [1.2077907 ]],
#
#        [[0.06363576],
#         [0.1163875 ],
#         [0.178109  ],
#         [0.24975316],
#         [0.33226183],
#         [0.42635104],
#         [0.5323782 ],
#         [0.65017164],
#         [0.7788676 ],
#         [0.916781  ],
#         [1.0614635 ],
#         [1.2099215 ]],
#
#        [[0.06356774],
#         [0.11614488],
#         [0.17762883],
#         [0.24912854],
#         [0.33165714],
#         [0.42601177],
#         [0.53260076],
#         [0.6512539 ],
#         [0.78102905],
#         [0.9201702 ],
#         [1.0662082 ],
#         [1.2160574 ]],
#
#        [[0.06360752],
#         [0.11636971],
#         [0.17837463],
#         [0.2508163 ],
#         [0.33477715],
#         [0.43107107],
#         [0.54005224],
#         [0.6613957 ],
#         [0.79399365],
#         [0.9359661 ],
#         [1.0846479 ],
#         [1.2366112 ]],
#
#        [[0.06366169],
#         [0.11667439],
#         [0.17918311],
#         [0.2524422 ],
#         [0.3375658 ],
#         [0.43535274],
#         [0.5460641 ],
#         [0.66928643],
#         [0.8038743 ],
#         [0.94783115],
#         [1.0981976 ],
#         [1.2513252 ]],
#
#        [[0.06373339],
#         [0.11689111],
#         [0.17964159],
#         [0.25325942],
#         [0.33886027],
#         [0.4371952 ],
#         [0.548507  ],
#         [0.67243713],
#         [0.8078292 ],
#         [0.9524866 ],
#         [1.1032976 ],
#         [1.2564653 ]],
#
#        [[0.06365518],
#         [0.1166102 ],
#         [0.17900825],
#         [0.25210938],
#         [0.33699617],
#         [0.4344454 ],
#         [0.5448298 ],
#         [0.6678842 ],
#         [0.8023692 ],
#         [0.94605154],
#         [1.095766  ],
#         [1.2477036 ]],
#
#        [[0.06369919],
#         [0.11679299],
#         [0.17945944],
#         [0.25294387],
#         [0.3383377 ],
#         [0.43649557],
#         [0.54780096],
#         [0.6717916 ],
#         [0.8070534 ],
#         [0.9511532 ],
#         [1.1007838 ],
#         [1.2521268 ]],
#
#        [[0.06369717],
#         [0.11677755],
#         [0.17937782],
#         [0.25274232],
#         [0.33804855],
#         [0.43619332],
#         [0.54741424],
#         [0.67113703],
#         [0.80581385],
#         [0.94893026],
#         [1.0972201 ],
#         [1.2470075 ]],
#
#        [[0.06369074],
#         [0.1167215 ],
#         [0.17922911],
#         [0.25254056],
#         [0.33787397],
#         [0.43598053],
#         [0.5469802 ],
#         [0.6701532 ],
#         [0.8038513 ],
#         [0.9455823 ],
#         [1.0922127 ],
#         [1.2402729 ]],
#
#        [[0.06366383],
#         [0.11664699],
#         [0.17916866],
#         [0.25259662],
#         [0.3380051 ],
#         [0.4360223 ],
#         [0.546611  ],
#         [0.66892976],
#         [0.80132645],
#         [0.9414191 ],
#         [1.0862714 ],
#         [1.2325838 ]],
#
#        [[0.06369957],
#         [0.1168572 ],
#         [0.17974807],
#         [0.25360757],
#         [0.3393846 ],
#         [0.43753454],
#         [0.5478654 ],
#         [0.66948336],
#         [0.80079097],
#         [0.93955237],
#         [1.0829622 ],
#         [1.2279145 ]],
#
#        [[0.06375513],
#         [0.11704202],
#         [0.17998667],
#         [0.2536955 ],
#         [0.33895645],
#         [0.43609202],
#         [0.5448869 ],
#         [0.66453856],
#         [0.7936403 ],
#         [0.93013734],
#         [1.0714737 ],
#         [1.2148144 ]],
#
#        [[0.06371011],
#         [0.11671467],
#         [0.17898427],
#         [0.25145912],
#         [0.3348048 ],
#         [0.42934218],
#         [0.5349806 ],
#         [0.65115434],
#         [0.7766984 ],
#         [0.9098834 ],
#         [1.0485147 ],
#         [1.190198  ]],
#
#        [[0.06358244],
#         [0.11622913],
#         [0.17778032],
#         [0.24906394],
#         [0.33072308],
#         [0.4231523 ],
#         [0.5264219 ],
#         [0.6401171 ],
#         [0.7633062 ],
#         [0.8945468 ],
#         [1.0320507 ],
#         [1.173673  ]],
#
#        [[0.06362872],
#         [0.11636522],
#         [0.17801909],
#         [0.24942076],
#         [0.3312544 ],
#         [0.4239885 ],
#         [0.52770954],
#         [0.64206225],
#         [0.7662085 ],
#         [0.8989256 ],
#         [1.038514  ],
#         [1.1825973 ]],
#
#        [[0.06357448],
#         [0.11613011],
#         [0.17745194],
#         [0.24840182],
#         [0.32974657],
#         [0.42199948],
#         [0.52535194],
#         [0.6396062 ],
#         [0.76422626],
#         [0.89817375],
#         [1.0395992 ],
#         [1.1858704 ]],
#
#        [[0.06356712],
#         [0.11613572],
#         [0.17755325],
#         [0.24877171],
#         [0.3305894 ],
#         [0.4235901 ],
#         [0.5280721 ],
#         [0.6440806 ],
#         [0.7712032 ],
#         [0.9081829 ],
#         [1.0528396 ],
#         [1.2020766 ]],
#
#        [[0.06360134],
#         [0.11630443],
#         [0.17804754],
#         [0.24981523],
#         [0.33247596],
#         [0.4267216 ],
#         [0.5330987 ],
#         [0.65179175],
#         [0.78218555],
#         [0.9226971 ],
#         [1.0706637 ],
#         [1.2226099 ]],
#
#        [[0.0636249 ],
#         [0.11642847],
#         [0.17835942],
#         [0.25046435],
#         [0.33372858],
#         [0.42911884],
#         [0.5373749 ],
#         [0.6585527 ],
#         [0.7917911 ],
#         [0.93508977],
#         [1.0854465 ],
#         [1.2391704 ]],
#
#        [[0.06364839],
#         [0.11648645],
#         [0.17850746],
#         [0.2508664 ],
#         [0.33482417],
#         [0.43156347],
#         [0.5417404 ],
#         [0.6652213 ],
#         [0.8007831 ],
#         [0.9461284 ],
#         [1.0980626 ],
#         [1.2528201 ]],
#
#        [[0.06361059],
#         [0.11639274],
#         [0.17842852],
#         [0.2511333 ],
#         [0.3359878 ],
#         [0.4341187 ],
#         [0.5460357 ],
#         [0.6712944 ],
#         [0.8084232 ],
#         [0.95497257],
#         [1.1076983 ],
#         [1.2628618 ]],
#
#        [[0.06367117],
#         [0.11669418],
#         [0.17942314],
#         [0.25349763],
#         [0.34034505],
#         [0.4409388 ],
#         [0.5554574 ],
#         [0.6831685 ],
#         [0.8223919 ],
#         [0.9705615 ],
#         [1.1243925 ],
#         [1.2801007 ]],
#
#        [[0.06371476],
#         [0.11702238],
#         [0.180452  ],
#         [0.2555804 ],
#         [0.3437062 ],
#         [0.44553098],
#         [0.5610307 ],
#         [0.6893694 ],
#         [0.8288643 ],
#         [0.97701603],
#         [1.1305757 ],
#         [1.2858279 ]],
#
#        [[0.06384879],
#         [0.11754592],
#         [0.18153295],
#         [0.2572557 ],
#         [0.34576383],
#         [0.4475952 ],
#         [0.56267524],
#         [0.69022983],
#         [0.8287163 ],
#         [0.9757422 ],
#         [1.128189  ],
#         [1.2824945 ]],
#
#        [[0.0638109 ],
#         [0.11722183],
#         [0.18046595],
#         [0.25471947],
#         [0.34089604],
#         [0.4395586 ],
#         [0.5508177 ],
#         [0.6742088 ],
#         [0.8085007 ],
#         [0.95165485],
#         [1.1009208 ],
#         [1.2531059 ]]], dtype=float32)

# %%
# data_y_test[-10:,0]

# %%
# data_x_test[-10:,0,-1]

# %%
# t = []
# for i in range(2000):
#     if data_y_test[:,0][i]>data_x_test[:,0,-1][i]:
#         t.append(1)
#     else:
#         t.append(0)
# len(t)

# %%
# p = []
# for i in range(2000):
#     if y_pred[:,0][i]>data_x_test[:,0,-1][i]:
#         p.append(1)
#     else:
#         p.append(0)
# len(p)

# %%
# n = 0
# for i in range(2000):
#     if t[i]==p[i]:
#         n=n+1
# n/2000
