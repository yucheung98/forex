# %%
from datetime import datetime
import MetaTrader5 as mt5
import pymysql, pytz
import pandas as pd 
import numpy as np

# %%
    """
    获取连续11小时的USDJPY收盘价数据
    """
    if not mt5.initialize():
        print("initialize() failed, error code =", mt5.last_error())
        quit()
#     # 将时区设置为UTC
#     timezone = pytz.timezone("Etc/UTC")
#     # 以UTC时区创建'datetime'对象，以避免实现本地时区偏移
#     utc_from = datetime(2020, 4, 15, tzinfo=timezone)
#     # 在UTC时区，获取----开始的11个EURUSD H4柱形图
    rates = mt5.copy_rates_from_pos('USDJPY', mt5.TIMEFRAME_D1, 1, 2010)
#     print(rates)
#     print(type(rates))
    ticks_frame = pd.DataFrame(rates)
#     ticks_frame['time']=pd.to_datetime(ticks_frame['time'], unit='s')
#     print(ticks_frame)
#     print(ticks_frame['close'])
#     close_list = ticks_frame['close'].tolist()
#     print(close_list)
#     df_EURUSD = pd.DataFrame(columns=['t1', 't2', 't3', 't4', 't5', 't6', 't7', 't8', 't9', 't10', 't11'])
#     for i in range(len(close_list)-10):
# #     print(close_list[i:i + 11])
#         df_EURUSD.loc[len(df_EURUSD)] = close_list[i:i + 11]
#     df_EURUSD = pd.DataFrame(columns=['close', 'change'])
    df_USDJPY = ticks_frame['close']

# %%
ticks_frame
# Out:
#             time     open     high      low    close  tick_volume  spread  \
# 0     1345593600  0.98889  0.99463  0.98888  0.99083        48370       6
# 1     1345680000  0.99083  0.99477  0.98839  0.99377        49063       3
# 2     1345766400  0.99376  0.99469  0.99033  0.99215        45070       5
# 3     1346025600  0.99166  0.99236  0.98890  0.99051        33476       3
# 4     1346112000  0.99052  0.99165  0.98417  0.98791        41906       9
# ...          ...      ...      ...      ...      ...          ...     ...
# 2005  1589500800  1.40501  1.41170  1.40182  1.41109        52792       0
# 2006  1589760000  1.41035  1.41131  1.39355  1.39355        40127       0
# 2007  1589846400  1.39351  1.39689  1.38663  1.39413        52367       0
# 2008  1589932800  1.39403  1.39605  1.38678  1.39001        43601       0
# 2009  1590019200  1.39009  1.39704  1.38909  1.39532        48372       0
#
#       real_volume
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0
# ...           ...
# 2005            0
# 2006            0
# 2007            0
# 2008            0
# 2009            0
#
# [2010 rows x 8 columns]

# %%
# close_array = np.array(ticks_frame['close'])
# len(close_array)

# %%
# for i in range(len(close_array)-1):
#     change = (close_array[i+1] - close_array[i])*1000
#     df_EURUSD.loc[i] = [close_array[i+1], change]

# %%
df_USDJPY
# Out:
# 0       0.99083
# 1       0.99377
# 2       0.99215
# 3       0.99051
# 4       0.98791
#          ...
# 2005    1.41109
# 2006    1.39355
# 2007    1.39413
# 2008    1.39001
# 2009    1.39532
# Name: close, Length: 2010, dtype: float64

# %%
    df_USDJPY.to_csv('USDJPY_data_D1.csv',encoding='utf_8_sig')
